# %% [markdown]
# https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0MB)
#      |████████████████████████████████| 12.0MB 255kB/s eta 0:00:01
# Requirement already satisfied: spacy>=2.2.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from en_core_web_sm==2.2.5) (2.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (41.4.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.23)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.17.3)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.3.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.2.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.22.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.36.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.25.6)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.8)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->en_core_web_sm==2.2.5) (7.2.0)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.5-cp37-none-any.whl size=12011740 sha256=679f069a5965b2a825a2afa9a61f9cf570246e750bd17dda999cd0465c42a113
#   Stored in directory: /private/var/folders/hw/b3bfbd8n08v9shjcjn1ldgxc0000gn/T/pip-ephem-wheel-cache-8sih58eq/wheels/6a/47/fb/6b5a0b8906d8e8779246c67d4658fd8a544d4a03a75520197a
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
text_e  = '''

Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most EPA materials.

World Bank data indicate that 3.7 billion people, about half the world's population, are exposed to more than 50 µg/m³ of PM2.5 on an annual basis, 5x the unit of measure for most of the findings below.

    Chess players make more mistakes on polluted days: "We find that an increase of 10 µg/m³ raises the probability of making an error by 1.5 percentage points, and increases the magnitude of the errors by 9.4%. The impact of pollution is exacerbated by time pressure. When players approach the time control of games, an increase of 10 µg/m³, corresponding to about one standard deviation, increases the probability of making a meaningful error by 3.2 percentage points, and errors being 17.3% larger." – Künn et al 2019.
    A 3.26x (albeit with very wide CI) increase in Alzheimer's incidence for each 10 µg/m³ increase in long-term PM2.5 exposure? "Short- and long-term PM2.5 exposure was associated with increased risks of stroke (short-term odds ratio 1.01 [per µg/m³ increase in PM2.5 concentrations], 95% CI 1.01-1.02; long-term 1.14, 95% CI 1.08-1.21) and mortality (short-term 1.02, 95% CI 1.01-1.04; long-term 1.15, 95% CI 1.07-1.24) of stroke. Long-term PM2.5 exposure was associated with increased risks of dementia (1.16, 95% CI 1.07-1.26), Alzheimer's disease (3.26, 95% 0.84-12.74), ASD (1.68, 95% CI 1.20-2.34), and Parkinson's disease (1.34, 95% CI 1.04-1.73)." – Fu et al 2019. Similar effects are seen in Bishop et al 2018: "We find that a 1 µg/m³ increase in decadal PM2.5 increases the probability of a dementia diagnosis by 1.68 percentage points."
    A study of 20,000 elderly women concluded that "the effect of a 10 µg/m³ increment in long-term [PM2.5 and PM10] exposure is cognitively equivalent to aging by approximately 2 years". – Weuve et al 2013.
    "Utilizing variations in transitory and cumulative air pollution exposures for the same individuals over time in China, we provide evidence that polluted air may impede cognitive ability as people become older, especially for less educated men. Cutting annual mean concentration of particulate matter smaller than 10 µm (PM10) in China to the Environmental Protection Agency’s standard (50 µg/m³) would move people from the median to the 63rd percentile (verbal test scores) and the 58th percentile (math test scores), respectively." – Zhang et al 2018.
    Stock market returns are lower on polluted days. "This estimate indicates that a one unit increase in PM2.5 decreases the daily percentage returns by 1.7%. Put differently, a one standard deviation increase in PM2.5 decreases the daily percentage returns by 11.9%, a substantial effect on daily NYSE returns." Hayes et al 2016.
    Baseball umpires make worse decisions on polluted days. "Unique characteristics of this setting combined with high-frequency data disentangle effects of multiple pollutants and identify previously under-explored acute effects. We find a 1 ppm increase in 3 hour CO causes an 11.5% increase in the propensity of umpires to make incorrect calls and a 10 µg/m³ increase in 12-hour PM2.5 causes a 2.6% increase." Archsmith et al 2018.
    Politicians use less complex speech on polluted days. "We apply textual analysis to convert over 100,000 verbal statements made by Canadian MPs from 2006 through 2011 into—among other metrics—speech-specific Flesch-Kincaid grade-level indices. This index measures the complexity of an MP’s speech by the number of years of education needed to accurately understand it. Conditioning on individual fixed effects and other controls, we show that elevated levels of airborne fine particulate matter reduce the complexity of MPs’s speeches. A high-pollution day, defined as daily average PM2.5 concentrations greater than 15 µg/m³, causes a 2.3% reduction in same-day speech quality. To put this into perspective, this is equivalent to the removal of 2.6 months of education." Heyes et al 2019.
    "Exposure to CO2 and VOCs at levels found in conventional office buildings was associated with lower cognitive scores than those associated with levels of these compounds found in a Green building." – Allen et al 2016. The effect seems to kick in at around 1,000 ppm of CO2.

'''

# %% [markdown]
# ## Mit Spacy NLP verarbeiten

# %%
article = nlp(text_e)
len(article.ents)
# Out:
# 91

# %%
print(article.ents)
# Out:
# (EPA, World Bank, 3.7 billion, about half, more than 50, annual, 5x, days, 10 µg/m³ raises the, 1.5, 9.4%, 10 µg/m³, about one, 3.2, 17.3%, 2019, CI, 10 µg/m³, 1.01, 95%, 1.01-1.02, 1.14, 95%, 1.08, 1.02, 95%, 1.01-1.04, 1.15, 95%, 1.07-1.24, 1.16, 95%, 1.07-1.26, 3.26, 95%, ASD, 1.68, 95%, 1.20-2.34, 1.34, 95%, 1.04-1.73, 2019, Bishop et al, 1 µg/m³, 1.68, 20,000, 10, approximately 2 years, Weuve, China, 10 µm, China, the Environmental Protection Agency, 50 µg/, the median to the 63rd, 58th, polluted days, one, PM2.5, daily, 1.7%, one, PM2.5, daily, 11.9%, NYSE, polluted days, 1, 3 hour, 11.5%, 10 µg/, 2.6%, 2018, polluted days, over 100,000, Canadian, 2006 through, 2011, Flesch-Kincaid, the number of years, MPs, daily, 2.3%, same-day, 2.6 months, Heyes et al 2019, Exposure to CO2, Allen et al 2016, around 1,000, CO2)

# %%
labels = [x.label_ for x in article.ents]  #label_ ist ein Befehl der Bibliothek
Counter(labels)  #Counter ist ein Python-Befehl.
# Out:
# Counter({'ORG': 5,
#          'CARDINAL': 25,
#          'DATE': 24,
#          'QUANTITY': 4,
#          'PERCENT': 15,
#          'MONEY': 2,
#          'PERSON': 5,
#          'GPE': 6,
#          'ORDINAL': 1,
#          'TIME': 1,
#          'NORP': 1,
#          'WORK_OF_ART': 2})

# %%
Counter(['a','a','a','b','c','c'])
# Out:
# Counter({'a': 3, 'b': 1, 'c': 2})

# %% [markdown]
# https://spacy.io/api/annotation

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('95%', 8), ('polluted days', 3), ('daily', 3)]

# %%
sentences = [x for x in article.sents]
#print(sentences[2])
sentences[3]
# Out:
# For example, cognitive effects are not mentioned in most EPA materials.

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5; direction: ltr">Its adverse effects on numerous health outcomes and general mortality are widely documented.</div>

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="036dcf581a4447f39f6fd8ff0c600b1e-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Air</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">pollution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">deal.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-3" stroke-width="2px" d="M550,182.0 C550,62.0 885.0,62.0 885.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-4" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-5" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-6" stroke-width="2px" d="M430,182.0 C430,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-036dcf581a4447f39f6fd8ff0c600b1e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,184.0 L898.0,172.0 882.0,172.0" fill="currentColor"/>
# </g>
# </svg>

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('\n\n', 'SPACE', '\n\n'),
#  ('Air', 'NOUN', 'air'),
#  ('pollution', 'NOUN', 'pollution'),
#  ('big', 'ADJ', 'big'),
#  ('deal', 'NOUN', 'deal')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[0])).ents])
# Out:
# {}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></br>Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EPA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  materials.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data indicate that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.7 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the world's population, are exposed to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  µg/m³ of PM2.5 on an
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5x
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the unit of measure for most of the findings below.</br></br>    Chess players make more mistakes on polluted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : &quot;We find that an increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³ raises the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  probability of making an error by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  percentage points, and increases the magnitude of the errors by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9.4%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . The impact of pollution is exacerbated by time pressure. When players approach the time control of games, an increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , corresponding to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  standard deviation, increases the probability of making a meaningful error by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  percentage points, and errors being
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  larger.&quot; – Künn et al
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>    A 3.26x (albeit with very wide
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) increase in Alzheimer's incidence for each
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  increase in long-term PM2.5 exposure? &quot;Short- and long-term PM2.5 exposure was associated with increased risks of stroke (short-term odds ratio
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.01
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  [per µg/m³ increase in PM2.5 concentrations],
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     95%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  CI
# <mark class="entity" style="background: #b

# %% [markdown]
# Jetzt noch die Bibliothek auf Deutsch runterladen:

# %%
# !python3 -m spacy download de_core_news_sm
# Out:
# Collecting de_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.2.5/de_core_news_sm-2.2.5.tar.gz#egg=de_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.2.5/de_core_news_sm-2.2.5.tar.gz (14.9MB)
#      |████████████████████████████████| 14.9MB 299kB/s eta 0:00:01
# Requirement already satisfied: spacy>=2.2.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from de_core_news_sm==2.2.5) (2.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.17.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.23)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (41.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.0)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.2.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.22.0)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/master/Library/Python/3.7/lib/python/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (7.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (1.25.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (4.36.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_sm==2.2.5) (7.2.0)
# Building wheels for collected packages: de-core-news-sm
#   Building wheel for de-core-news-sm (setup.py) ... done
#   Created wheel for de-core-news-sm: filename=de_core_news_sm-2.2.5-cp37-none-any.whl size=14907056 sha256=7fa39313619c4058ad2fc575a555b54fc13c654ae226e46ed8ab68503d49bc42
#   Stored in directory: /private/var/folders/hw/b3bfbd8n08v9shjcjn1ldgxc0000gn/T/pip-ephem-wheel-cache-awgp3lxf/wheels/ba/3f/ed/d4aa8e45e7191b7f32db4bfad565e7da1edbf05c916ca7a1ca
# Successfully built de-core-news-sm
# Installing collected packages: de-core-news-sm
#   Found existing installation: de-core-news-sm 2.0.0
#     Uninstalling de-core-news-sm-2.0.0:
#       Successfully uninstalled de-core-news-sm-2.0.0
# Successfully installed de-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')

# %%
text_d = '''Schon kurz nach Amtsantritt zeigte William Barr seine Marschrichtung auf. Der Justizminister liess eine irreführende Zusammenfassung des Mueller-Reports veröffentlichen und sprach den Präsidenten eigenmächtig frei von der Anklage, das Gesetz behindert zu haben.
Wenig später beklagte er sich vor dem Senat, gegen den Präsidenten sei «spioniert» worden. Dann setzte er einen eigenen Sonderermittler ein, der diese «Spionage» untersuchen soll, obwohl ein Inspector General diesen Vorwurf bereits entkräftet hatte.
Um ganz sicher zu sein, reiste Barr höchstpersönlich nach London und Rom, um Zeugen für die «Spionage» aufzutreiben, allerdings ohne Erfolg.
Attorney General William Barr smiles at President Donald Trump as he signs an executive order during the International Association of Chiefs of Police Annual Conference and Exposition, at the McCormick Place Convention Center Chicago, Monday, Oct. 28, 2019, in Chicago. (AP Photo/Evan Vucci) Donald Trump,WIlliam Barr
Mehr als nur Diener seines Herrn: William Barr und Donald Trump. Bild: AP
Der Verdacht liegt nahe, dass Barr ein opportunistischer Hack sei, ein willfähriger Diener seines Herrn. Der Eindruck trügt. Der Justizminister ist ein Überzeugungstäter, der sich in einem Krieg gegen Sozialisten und Progressive wähnt. Das hat er am vergangenen Freitag in einer Rede vor der Federalist Society klar gemacht. Die Federalist Society ist ein Netzwerk von konservativen Juristen, das in der Reagan-Ära gegründet wurde.
Barr ist ein gelehriger Schüler von Edwin Meese III. Dieser war Justizminister in der Reagan-Regierung. Einer breiten Öffentlichkeit bekannt wurde er als lächerlicher Pornografie-Jäger und Teilnehmer dubioser Finanzgeschäfte. Unter Juristen machte Meese sich einen Namen als Vertreter des «Originalismus», einer Rechtslehre, die sich auf die wörtliche Auslegung der Verfassung der Gründerväter beruft.
epa07906393 US President Donald J. Trump presents the Presidential Medal of Freedom to Edwin Meese at the White House in Washington, DC, USA, 08 October 2019. Meese, 87, served as the Attorney General during the Reagan administration. EPA/Chris Kleponis / POOL
Vom Präsidenten mit der Freiheitsmedaille geehrt: Der ehemalige Justizminister Edwin Meese III. Bild: EPA
In seiner Rede beruft sich Barr ausdrücklich auf diese Doktrin. «Für die Zukunft unserer Nation ist es von entscheidender Bedeutung, dass wir die volle Kraft der Prinzipien der Gründerväter wiederherstellen», führte Barr aus. «Vor allem geht es um die Vision einer starken und unabhängigen Exekutive, die vom gesamten Volk gewählt wird.»
Mehr zu Donald Trump:

    Die perversen Folgen von Trumps Steuergeschenken
    Alles, was du zu Trumps neuesten Twitter-Attacken auf Zeugen wissen musst
    Trumps zweiter tödlicher Telefonanruf
    Das «Who is who» des Impeachment: Diese Zeugen treten in den Hearings auf

Die Originalisten stellen die Gewaltenteilung zwischen Regierung, Parlament und Justiz in Frage und berufen sich dabei auf die Gründerväter, allerdings mit dubiosen Beweisen.
Justizminister Meese hat diese Doktrin in einer Zeit propagiert, in der sein Präsident unter massivem Druck stand. Reagans dubioser Iran-Contra-Deal wurde vom Parlament kritisch unter die Lupe genommen, seine eigenmächtige Politik der Deregulierung heftig kritisiert.
Ed Meese scharte in dieser Zeit junge konservative Juristen um sich. Diese Truppe verstand sich als eine Art juristischer Prätorianergarde des Präsidenten. William Barr war einer von ihnen. Als Justizminister will er diese Tradition fortsetzen. «Ich bin stolz, unter Trump als Justizminister zu dienen», erklärte er. «Er führt diese Tradition weiter.»
Für die Originalisten ist die Macht des Präsidenten uneingeschränkt. Nur so kann er die Gesellschaft vor dem drohenden Unheil bewahren. Die Kontrolle durch den Kongress ist in den Augen Barrs eine «konstante Belästigung» des Präsidenten mit dem Ziel, die Fundamente der Gesellschaft zu untergraben.'''

# %%
import de_core_news_sm
nlp = de_core_news_sm.load()

# %%
article2 = nlp(text_d)
len(article2.ents)
# Out:
# 50

# %%
displacy.render(article2, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Schon kurz nach Amtsantritt zeigte
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Barr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  seine Marschrichtung auf. Der Justizminister liess eine irreführende Zusammenfassung des
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mueller-Reports
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  veröffentlichen und sprach den Präsidenten eigenmächtig frei von der Anklage, das Gesetz behindert zu haben.</br>Wenig später beklagte er sich vor dem Senat, gegen den Präsidenten sei «spioniert» worden. Dann setzte er einen eigenen Sonderermittler ein, der diese «Spionage» untersuchen soll, obwohl ein Inspector General diesen Vorwurf bereits entkräftet hatte.</br>Um ganz sicher zu sein, reiste
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  höchstpersönlich nach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  und
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , um Zeugen für die «Spionage» aufzutreiben, allerdings ohne Erfolg.</br>Attorney General
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Barr smiles at President Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  as he signs an executive order during
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Association of Chiefs of Police Annual Conference and Exposition
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at the McCormick Place Convention Center Chicago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oct
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . 28, 2019, in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chicago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Photo/Evan Vucci)
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WIlliam Barr
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# Mehr als nur Diener seines Herrn:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Barr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Bild:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AP
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Der Verdacht liegt nahe, dass
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ein opportunistischer Hack sei, ein willfähriger Diener seines Herrn. Der Eindruck trügt. Der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Justizminister
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ist ein Überzeugungstäter, der sich in einem
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Krieg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  gegen Sozialisten und Progressive wähnt. Das hat er am vergangenen Freitag in einer Rede vor der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Federalist Society
#     <span style="font-size: 0.8em; font-w

# %% [markdown]
# Erkennung nicht so doll, auf Deutsch.

# %%
labels = [x.label_ for x in article2.ents]  #label_ ist ein Befehl der Bibliothek
Counter(labels)  #Counter ist ein Python-Befehl.
# Out:
# Counter({'PER': 25, 'ORG': 7, 'LOC': 11, 'MISC': 7})

# %%
for entity in article2.ents:
    print(entity, entity.label_)
# Out:
# William Barr PER
# Mueller-Reports ORG
# Barr PER
# London LOC
# Rom LOC
# William Barr smiles at President Donald Trump PER
# the International Association of Chiefs of Police Annual Conference and Exposition ORG
# at the McCormick Place Convention Center Chicago MISC
# Monday LOC
# Oct LOC
# Chicago LOC
# AP ORG
# Donald Trump PER
# WIlliam Barr
#  PER
# William Barr PER
# Donald Trump PER
# AP
#  ORG
# Barr PER
# Justizminister LOC
# Krieg MISC
# Federalist Society ORG
# Federalist Society ORG
# Reagan-Ära LOC
# Edwin Meese III PER
# Reagan-Regierung MISC
# Meese PER
# US LOC
# Donald J. Trump PER
# Washington LOC
# DC LOC
# USA LOC
# Meese PER
# EPA/Chris MISC
# POOL ORG
# Edwin Meese III PER
# EPA
#  MISC
# Barr PER
# Barr PER
# Donald Trump PER
# Trumps Steuergeschenken PER
# du zu Trumps PER
# musst PER
# Hearings MISC
# massivem Druck PER
# Reagans PER
# Lupe PER
# Zeit MISC
# William Barr PER
# Trump PER
# Barrs PER

# %% [markdown]
# Mit dem englischen Decoder:

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
article2 = nlp(text_d)
len(article2.ents)
# Out:
# 129

# %%
labels = [x.label_ for x in article2.ents]  #label_ ist ein Befehl der Bibliothek
Counter(labels)  #Counter ist ein Python-Befehl.
# Out:
# Counter({'ORG': 18,
#          'PERSON': 81,
#          'FAC': 6,
#          'PRODUCT': 3,
#          'GPE': 10,
#          'WORK_OF_ART': 3,
#          'DATE': 3,
#          'NORP': 4,
#          'EVENT': 1})

# %%
for entity in article2.ents:
    print(entity, entity.label_)
# Out:
# Schon ORG
# Amtsantritt ORG
# William Barr PERSON
# Marschrichtung auf PERSON
# Der Justizminister PERSON
# Zusammenfassung des Mueller-Reports FAC
# von der Anklage PRODUCT
# das Gesetz behindert zu haben PERSON
# Wenig PERSON
# Dann PERSON
# Vorwurf ORG
# zu sein PERSON
# Barr PERSON
# London GPE
# Rom PERSON
# Zeugen ORG
# aufzutreiben PERSON
# Erfolg WORK_OF_ART
# William Barr PERSON
# Donald Trump PERSON
# the International Association of Chiefs of Police Annual Conference and Exposition ORG
# the McCormick Place Convention Center Chicago ORG
# Monday, Oct. 28, 2019 DATE
# Chicago GPE
# AP Photo/ ORG
# Donald Trump PERSON
# WIlliam Barr
#  PERSON
# Mehr WORK_OF_ART
# William Barr PERSON
# Donald Trump PERSON
# AP ORG
# Der Verdacht liegt nahe PERSON
# Barr ein PERSON
# Hack sei PERSON
# ein ORG
# Diener PERSON
# Der Eindruck PERSON
# Der Justizminister PERSON
# ein Überzeugungstäter PERSON
# der sich PERSON
# einem GPE
# Sozialisten FAC
# Das PERSON
# Freitag PERSON
# Rede PERSON
# Federalist Society ORG
# ein Netzwerk von konservativen Juristen PERSON
# Reagan PERSON
# Barr PERSON
# ein gelehriger PERSON
# Schüler von PERSON
# Edwin Meese III PERSON
# Justizminister PERSON
# Reagan PERSON
# Einer PERSON
# Öffentlichkeit bekannt wurde PERSON
# Pornografie PERSON
# Finanzgeschäfte PERSON
# Meese NORP
# Namen PERSON
# Vertreter des « FAC
# Rechtslehre PERSON
# sich auf PERSON
# Auslegung GPE
# US GPE
# Donald J. Trump PERSON
# the Presidential Medal of Freedom ORG
# Edwin Meese PERSON
# the White House FAC
# Washington, DC GPE
# USA GPE
# 08 October 2019 DATE
# Meese, 87 DATE
# Reagan PERSON
# EPA ORG
# Chris Kleponis PERSON
# Vom Präsidenten ORG
# Freiheitsmedaille PERSON
# Der ehemalige Justizminister Edwin Meese III PERSON
# EPA ORG
# Rede PERSON
# sich Barr PERSON
# Für die Zukunft WORK_OF_ART
# Bedeutung PERSON
# dass wir PERSON
# Kraft FAC
# Prinzipien PERSON
# führte Barr aus PERSON
# Vor allem geht PERSON
# Vision ORG
# Volk FAC
# Donald Trump PERSON
# Folgen von Trumps Steuergeschenken
#      PERSON
# du zu Trumps PERSON
# Twitter- ORG
# Trumps PERSON
# Telefonanruf NORP
# Diese Zeugen PERSON
# Gewaltenteilung zwischen Regierung, PERSON
# Justiz PERSON
# sich dabei auf PERSON
# Gründerväter PERSON
# Beweisen PERSON
# Justizminister Meese PERSON
# diese Doktrin PERSON
# Zeit propagiert GPE
# Druck PERSON
# Reagans NORP
# Iran-Contra EVENT
# Politik ORG
# Deregulierung heftig kritisiert PRODUCT
# Ed Meese PERSON
# Zeit PERSON
# Diese Truppe PERSON
# William Barr war PERSON
# von ihnen PERSON
# Als Justizminister PERSON
# Ich bin stolz PERSON
# Trump PRODUCT
# Justizminister zu dienen» PERSON
# Für PERSON
# Macht des Präsidenten ORG
# Nur PERSON
# kann PERSON
# Gesellschaft NORP
# Unheil GPE
# Kontrolle GPE
# Ziel PERSON
# Fundamente der Gesellschaft zu untergraben PERSON

# %% [markdown]
# Also mit dem Englischen Decoder macht er viele Fehler. Ist eigentlich auch nicht überraschend.
