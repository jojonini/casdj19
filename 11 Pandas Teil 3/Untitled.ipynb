# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path='/usr/local/bin/chromedriver')
driver.get("https://www.tagesanzeiger.ch")
html = driver.page_source
print(html)
# Out:
# <html xmlns="//www.w3.org/1999/xhtml"><head>
#
#        <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta http-equiv="Pragma" content="no-cache">
# <meta http-equiv="Expires" content="-1">
# <!-- head_title --> <meta name="robots" content="index, follow, noarchive">
# <meta name="description" content="Nachrichten, Analysen, Bilder und Video zu Politik, Wirtschaft, Sport, Kultur, Wissen, Technik, Auto und mehr.">
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss_ticker.html">
#
# <link rel="stylesheet" type="text/css" href="https://files.newsnetz.ch/cdn/swiper/2/dist/idangerous.swiper.css">
# <link rel="stylesheet" type="text/css" href="https://files.newsnetz.ch/cdn/nn2/framework/0.1/styles/sprites.css?v=238">
# <link rel="stylesheet" type="text/css" href="https://files.newsnetz.ch/cdn/nn2/desktop/0.1/styles/desktop.css?v=238">
# <!-- <link rel="stylesheet" type="text/css" href="https://files.newsnetz.ch/css/exportedFromNN2/styles/desktop.css?v=238"> -->
#
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/scoreboard.css?v=1571039845" type="text/css">
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/liveticker.css?v=1571029204" type="text/css">
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/slideshow.css?v=1571000312" type="text/css">
#
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/baseStyles_v5.css?v=1571044763" type="text/css">
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/TA_styles_v5.css?v=1571049442" type="text/css">
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/TA_fontStyles.css?v=1571044300" type="text/css">
# <!--[if IE]>
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/base_stylesIE_v4.css?v=1571046957" type="text/css" />
# <link rel="stylesheet" href="https://files.newsnetz.ch/css/TA_stylesIE_v4.css?v=1571039751" type="text/css" />
# <![EndIf]-->
#
# <link rel="stylesheet" media="print" href="https://files.newsnetz.ch/css/print_red.css" type="text/css">
# <title>tagesanzeiger.ch: Nichts verpassen</title>
#
#
# <!-- Google Analytics tagesanzeiger.ch -->
# <script type="text/javascript" src="https://cdn.krxd.net/userdata/get?pub=be7d9a40-d3d2-456f-a3c6-0aa6f4898c19&amp;technographics=1&amp;callback=Krux.ns.tamedia.kxjsonp_userdata"></script><script type="text/javascript" src="https://beacon.krxd.net/optout_check?callback=Krux.ns.tamedia.kxjsonp_optOutCheck"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2019100301.js"></script><script type="text/javascript" src="https://consumer.krxd.net/consent/set/be7d9a40-d3d2-456f-a3c6-0aa6f4898c19?idt=device&amp;dt=kxcookie&amp;dc=1&amp;al=1&amp;tg=1&amp;cd=1&amp;sh=1&amp;re=0&amp;callback=Krux.ns.tamedia.kxjsonp_consent_set_1"></script><script type="text/javascript" src="https://consumer.krxd.net/consent/get/be7d9a40-d3d2-456f-a3c6-0aa6f4898c19?idt=device&amp;dt=kxcookie&amp;callback=Krux.ns.tamedia.kxjsonp_consent_get_0"></script><script src="https://connect.facebook.net/signals/config/285088265237984?v=2.9.5&amp;r=stable" async=""></script><script src="https://connect.facebook.net/de_DE/sdk.js?hash=b9044273d9ee62f1772e91fcb9fca66e&amp;ua=modern_es6" async="" crossorigin="anonymous"></script><script async="" src="//cdn.krxd.net/ctjs/controltag.js.05f9d0dad02f8a1b0b028b868bc3a3e2"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="//static.ads-twitter.com/uwt.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NMD6327&amp;l=dataLayer"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-KX8KLM9&amp;l=dataLayer"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-KSCR4BX&amp;l=dataLayer"></script><script id="facebook-jssdk" src="//connect.facebook.net/de_DE/sdk.js#xfbml=1&amp;version=v2.3&amp;appId=147124108642216"></script><script async="" type="text/javascript" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-B35JQ84"></script><script type="text/javascript" async="" src="https://track.tagesanzeiger.ch/cre-1.0/tracking/tracking.js"></script><script type="text/javascript" async="" src="https://track.tagesanzeiger.ch/cre-1.0/static/tracking/1.0/templateclient.js"></script><script type="text/javascript" async="" src="https://track.tagesanzeiger.ch/cre-1.0/cockpit/platform/tamedia/shop/tagesanzeiger/api/templatesets.js"></script><script type="text/javascript" src="https://qs-ssl.wemfbox.ch/?tagi-ssl//CP//home"></script><script type="text/javascript" async="" src="https://ssl.google-analytics.com/ga.js"></script><script type="text/javascript">
#
# 	var _gaq = _gaq || [];
# 	_gaq.push(['first._setAccount', 'UA-431029-1']);
# 	_gaq.push(['first._setDomainName', 'tagesanzeiger.ch']);
# 	_gaq.push(['first._trackPageview']);
# 	_gaq.push(['second._setAccount', 'UA-431029-7']);
# 	_gaq.push(['second._setDomainName', 'tagesanzeiger.ch']);
# 	_gaq.push(['second._trackPageview']);
#
# 	(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : '//www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	})();
#
# </script>
# <!-- /Google Analytics tagesanzeiger.ch -->
#
#
#         <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:200,300,400,600,700,900" rel="stylesheet" type="text/css">
#
#
#         <!-- BEGIN Krux Control Tag for "tagesanzeiger.ch" -->
# <!-- Source: /controltag?confid=KVqVXOwf&site=tagesanzeiger.ch&edit=1 -->
# <!-- END Krux Controltag -->
#
# <style type="text/css">body .ad-outside-right {
#   position: absolute;
#   top: 28px; }
#   body .ad-outside-right.ad-position-sticky {
#     position: fixed; }
#   body .ad-outside-right.ad-position-left {
#     left: calc(50% + 498px); }
#     @media screen and (max-width: 1626px) {
#       body .ad-outside-right.ad-position-left {
#         left: calc(100% - 314px); } }
#     @media screen and (max-width: 1323px) {
#       body .ad-outside-right.ad-position-left {
#         left: 1010px; } }
#
# body .ad-outside-left {
#   position: absolute;
#   top: 28px; }
#   body .ad-outside-left.ad-position-sticky {
#     position: fixed; }
# </style><style type="text/css">div.as-oil {
#   font-family: SoleSerifRegular, Georgia, Times, serif; }
#   div.as-oil div.as-oil__heading, div.as-oil div.as-oil-cpc__row-title, div.as-oil div.as-oil-cpc__purpose-header {
#     font-family: SoleSerifMedium, Georgia, Times, serif; }
#   div.as-oil button.as-oil__btn-optin, div.as-oil span.as-oil__btn-blue, div.as-oil button.as-oil-cpc__switch input:checked ~ .as-oil-cpc__slider {
#     background: #007abf;
#     border: 1px solid #007abf; }
#   div.as-oil button.as-oil__btn-optin:hover, div.as-oil span.as-oil__btn-blue:hover, div.as-oil button.as-oil__btn-blue:hover {
#     background: #007abf; }
#   div.as-oil .as-oil-cpc__status {
#     color: black; }
#   div.as-oil label.as-oil-cpc__switch input:checked ~ .as-oil-cpc__slider {
#     background-color: #007abf; }
#   div.as-oil label.as-oil-cpc__switch input:checked ~ .as-oil-cpc__slider:before {
#     background-color: white; }
#   div.as-oil a.as-oil-cpc__category-link--active {
#     border-right: 2px solid #007abf; }
#   div.as-oil svg.as-oil-icon-plus, div.as-oil svg.as-oil-icon-minus {
#     stroke: #007abf; }
#
# #tagesanzeiger div.as-oil .as-oil-cpc__switch {
#   position: absolute;
#   display: inline-block; }
#
# #tagesanzeiger div.as-oil .as-oil__heading {
#   font-size: 1.8rem; }
#
# #tagesanzeiger div.as-oil .as-oil__intro-txt {
#   font-size: 1.4rem; }
#
# #tagesanzeiger div.as-oil .as-oil-cpc__row-title {
#   font-size: 1.6rem; }
#
# #tagesanzeiger div.as-oil .as-oil-cpc__purpose-header {
#   padding-right: 15px;
#   font-size: 1.4rem; }
#
# #tagesanzeiger div.as-oil .as-oil-cpc__purpose-text {
#   font-size: 1.4rem; }
#
# #tagesanzeiger div.as-oil .as-oil__btn-cpc {
#   font-size: 1.4rem; }
#
# #tagesanzeiger div.as-oil .as-js-btn-activate-all, #tagesanzeiger div.as-oil as-js-btn-deactivate-all {
#   font-size: 1.4rem; }
# </style><script id="oil-configuration" type="application/configuration">{"publicPath":"https://tdn.da-services.ch/libs/oil/1.2.5/","publicPathLang":"https://tdn.da-services.ch/libs/oil/lang/","gdpr_applies_globally":false,"advanced_settings":false,"default_to_optin":true,"advanced_settings_purposes_default":true,"locale_url":"https://tdn.da-services.ch/libs/oil/lang/lang_de.json","poi_activate_poi":false,"poi_hub_origin":"//tdn.da-services.ch","poi_hub_path":"/libs/oil/1.2.5/hub.html","poi_group_name":"TamediaAG","poi_subscriber_set_cookie":true,"iabVendorListUrl":"https://tdn.da-services.ch/libs/oil/lang/myVendorlist.json"}</script><script src="https://tdn.da-services.ch/libs/oil/1.2.5/oil.1.2.5-RELEASE.min.js"></script><link rel="preconnect" crossorigin="crossorigin" href="https://securepubads.g.doubleclick.net/"><script type="text/javascript" src="https://tdn.da-services.ch/libs/prebid2.31.0.js" async=""></script><script type="text/javascript" src="https://cdn.krxd.net/controltag/KVqVXOwf.js" async=""></script><script charset="utf-8" src="https://tdn.da-services.ch/libs/oil/1.2.5/1.1.2.5-RELEASE.chunk.js"></script><script charset="utf-8" src="https://tdn.da-services.ch/libs/oil/1.2.5/0.1.2.5-RELEASE.chunk.js"></script><style type="text/css">.as-oil__btn-cpc,.as-oil__intro-txt--link{color:#262626}.dark .as-oil__btn-cpc,.dark .as-oil__intro-txt--link{color:#f5f5f5}.dark .as-oil__btn-cpc:hover,.dark .as-oil__intro-txt--link:hover{color:#dcdcdc}.as-oil__btn-cpc:hover,.as-oil__intro-txt--link:hover{color:#0d0d0d;background-color:transparent}.as-oil{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;position:fixed;z-index:2147483647;bottom:0;left:0;width:100%;font-family:Helvetica Neue,Helvetica,Arial,sans-serif;color:#262626;font-size:14px}.as-oil,.as-oil *,.as-oil:after,.as-oil :after,.as-oil:before,.as-oil :before{box-sizing:border-box}.as-oil.dark{color:#f5f5f5}.as-oil a{cursor:pointer}@media (max-width:600px){.as-oil-fixed{position:fixed;bottom:0;left:0;height:100%;width:100%;overflow-y:scroll}}.as-oil-content-overlay{position:absolute;width:100%;bottom:0;left:0;padding:2rem 5rem;background-color:#f9f9f9;opacity:.97;box-shadow:0 -8px 20px 0 rgba(0,0,0,.2)}.as-oil-content-overlay:after{content:"";display:table;clear:both}.dark .as-oil-content-overlay{background-color:#262626}.small .as-oil-content-overlay{padding:.5rem!important}@media (max-width:600px){.as-oil-content-overlay{padding:1rem!important}}.as-oil__heading{max-width:840px;font-size:1.45rem;font-weight:600;line-height:1.15}.as-oil__heading:first-of-type{margin-top:0}.small .as-oil__heading{display:none}@media (max-width:600px){.as-oil__heading{margin:.5rem 0;font-size:1rem;line-height:1.3333;text-align:center}}.as-oil__intro-txt{display:inline-block;min-width:75%;max-width:75%;font-size:.9375rem;font-weight:400;line-height:1.4}.small .as-oil__intro-txt{margin:0 0 0 1rem}@media (max-width:600px){.small .as-oil__intro-txt{margin:.5rem 0}}@media (max-width:600px){.as-oil__intro-txt{margin:.5rem 0;min-width:100%;max-width:100%}}.as-oil__intro-txt--link{padding:4px 1px 0;margin:0 1px;text-decoration:underline}@media (min-width:601px) and (max-width:1023px){.as-oil-l-buttons{max-width:24%}}.as-oil__btn-optin{min-width:160px;min-height:42px;margin:0;padding:.5rem 1rem;font-size:1.1rem;font-weight:700;border:none;border-radius:3px;outline:none;cursor:pointer;color:#fff;background-color:#3f7edf;transition:opacity .8s ease 0s}.small .as-oil__btn-optin{min-width:120px;min-height:32px}@media (max-width:600px){.as-oil__btn-optin{width:100%;min-width:auto;padding:0}}.as-oil__btn-optin:hover{color:#f2f2f2;background-color:#2264c9}.as-oil__btn-optin.as-oil__btn-optin-clicked{opacity:.3}.as-oil__btn-blue{min-width:160px;min-height:42px;margin:0;padding:.5rem 1rem;font-size:1.1rem;font-weight:700;border:none;border-radius:3px;outline:none;cursor:pointer;color:#fff;background-color:#3f7edf}.small .as-oil__btn-blue{min-width:120px;min-height:32px}@media (max-width:600 ...
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_button{text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidde ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}</style><script async="" src="//track.tagesanzeiger.ch/cre-1.0/tracking/call.js?width=1440&amp;height=900&amp;dpi_x=96&amp;dpi_y=96&amp;tracking_id=1647367407775419207&amp;_c=cre_callback_9497&amp;action=pagecomplete&amp;origin=web&amp;serviceid=tagesanzeiger&amp;contentid=%2F&amp;cms_id=0&amp;channel=home&amp;adblocker=no&amp;_u=https%3A%2F%2Fwww.tagesanzeiger.ch%2F&amp;_r=" id="jsonp_9497"></script></head>
# <body onload="setAdsOnLoad()">
#
#
#     <img src="https://tda.tagesanzeiger.ch/in/newsnet/in.gif" width="1" height="1" display="none"><script src="https://w.tda.io/scripts/newsnet/dakt.min.js" async="" defer=""></script>
#
#
# 				<div style="position:absolute">
# 					<script language="JavaScript" type="text/javascript"> <!--
# 						var WEMF2="https://newsnetz-ssl.wemfbox.ch/cgi-bin/ivw/CP/tagi-ssl/";
#                         if (navigator.userAgent.match(/iPad/gi)) {
#                             WEMF2 = "https://newsnetz-ssl.wemfbox.ch/cgi-bin/ivw/CP/tagi-ssl/mobile/tablet/web/";
#                         }
# 						document.write("<img src='"+WEMF2+"home?r="+escape(document.referrer)+"&d="+(Math.random()*100000)+" ' width='1' height='1' alt='' />");
# 						// -->
# 					</script><img src="https://newsnetz-ssl.wemfbox.ch/cgi-bin/ivw/CP/tagi-ssl/home?r=&amp;d=61918.66593618056 " width="1" height="1" alt="">
# 					<noscript>
# 						<img src="https://newsnetz-ssl.wemfbox.ch/cgi-bin/ivw/CP/tagi-ssl/home" width="1" height="1" alt="" />
# 					</noscript>
# 				</div>
#
# 			<div style="position:absolute">
# 				<script language="JavaScript" type="text/javascript"> <!--
# 					var WEMF="//tagi-ssl.wemfbox.ch/cgi-bin/ivw/CP/";
#                     if (navigator.userAgent.match(/iPad/gi)) {
#                             WEMF="//tagi-ssl.wemfbox.ch/cgi-bin/ivw/CP/mobile/tablet/web/";
#                     }
# 					document.write("<img src='"+WEMF+"home?r="+escape(document.referrer)+"&d="+(Math.random()*100000)+"' width='1' height='1' alt='' />");
# 					// -->
# 				</script><img src="//tagi-ssl.wemfbox.ch/cgi-bin/ivw/CP/home?r=&amp;d=82951.02482230122" width="1" height="1" alt="">
# 				<noscript>
# 					<img src="//tagi-ssl.wemfbox.ch/cgi-bin/ivw/CP/home" width="1" height="1" alt="" />
# 				</noscript>
# 				<script language="Javascript">var szmvars="tagi-ssl//CP//home";</script>
# 				<script language="Javascript" src="//tagi-ssl.wemfbox.ch/2004/01/survey.js"></script>
# 			</div>
#
#
#
# 		<script>
#             var track_wemf = function(url, callback)
#             {
#                 url = (url==null) ? '' : url;
#
# 				var WEMF="//tagi-ssl.wemfbox.ch/cgi-bin/ivw/CP/";
# 				track_wemf_do(WEMF+''+url);
#
#
# 				var WEMF2="https://newsnetz-ssl.wemfbox.ch/cgi-bin/ivw/CP/tagi-ssl/";
# 				track_wemf_do(WEMF2+''+url);
#
#             }
#
#             var track_wemf_do = function(url2, callback)
#             {
#                 var img = new Image();
#                 if(typeof callback === "function") {
#                     $(img).load(callback);
#                 }
#                 img.src = url2 + "?rnd=" + parseInt(new Date().getTime() * Math.random(), 10);
#             }
# 		</script>
#
#
#     <!-- head_scripts_optimized start -->
# <script src="https://files.newsnetz.ch/scripts/updated/jquery-1.4.2.min.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/updated/ui/jquery.ui.core.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/updated/ui/jquery.ui.widget.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/updated/ui/jquery.ui.tabs.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/updated/jquery.pagination.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.getUrlParam.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery-validate-1.5.2/jquery.validate.min.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery-validate-1.5.2/localization/messages_de.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/easyTooltip.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.form.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.flash.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.cookie.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.url.packed.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/jquery.crypt.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/ajax.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/swfobject.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/misc6.js?id=16" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/ad_red.js" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/dimension_watcher.js"></script>
# <script>
# 	DimensionWatcher.watchIframeContent();
# </script>
#
#         <!-- Includes used for framework.js, nn2 slideshow and nn2 comments -->
# <script src="https://files.newsnetz.ch/cdn/html5shiv/3/dist/html5shiv.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/es5-shim/4/es5-shim.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/es5-shim/4/es5-sham.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/loader.js/3/loader.js"></script>
# <script src="https://files.newsnetz.ch/cdn/jquery/1/dist/jquery.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/jquery-simple-placeholder/jquery.simpleplaceholder.js"></script>
# <script src="https://files.newsnetz.ch/cdn/hammer.js/2/hammer.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/handlebars/3/handlebars.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/rsvp/3/rsvp.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/swiper/2/dist/idangerous.swiper.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/react/0.14/react-with-addons.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/react/0.14/react-dom.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/lodash/3/lodash.min.js"></script>
# <script src="https://files.newsnetz.ch/cdn/postscribe/1/dist/postscribe.min.js"></script>
#
# <script src="//www.google-analytics.com/analytics.js"></script>
# <script src="//platform.instagram.com/de_de/embeds.js"></script>
#
# <script type="text/javascript">
#     // Used for app.js and framework.js
#     window.cre_jq = jQuery.noConflict(true);
# </script>
#
# <!-- Used for new nn2 slideshow -->
# <script src="https://files.newsnetz.ch/cdn/nn2/framework/0.1/framework.js?v=270"></script>
# <!-- <script src="https://files.newsnetz.ch/scripts/exportedFromNN2/framework.js?v=270" type="text/javascript"></script> -->
#
# <script>
#     // Load statistics for slideshow and comments from NN2 framework
#     (function($) {
#         var config = require("framework/config").config;
#
#         config.configure({
#             env: "desktop",
#             apiUrl: "https://m.tagesanzeiger.ch/api",
#             ads: {
#                 enabled: true
#             }
#         });
#
#         if (window.location.host.indexOf("devlocal")) {
#             config.configure({
#                 apiUrl: config.apiUrl.replace("devlocal", "ch")
#             });
#         }
#
#         $.getJSON(config.apiUrl + "/sites/default").then(function(payload) {
#             require("framework/statistics").statistics.init({
#                 env: config.env,
#                 gtm: {
#                     id: payload.site.gtm_id
#                 }
#             }, {
#                 "google_analytics": {
#                     "customVars": [{
#                         "name": "device_characteristics",
#                         "value": "desktop"
#                     }, {
#                         "name": "app_mode",
#                         "value": "browser"
#                     }, {
#                         "name": "version",
#                         "value": config.version
#                     }, {
#                         "name": "ad_blocker",
#                         "value": !window.adblockJsFile
#                     }]
#                 }
#             });
#         });
#     })(cre_jq);
# </script>
#
# <script src="https://files.newsnetz.ch/scripts/liveticker.js?v=220" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/slideshow.js?v=262" type="text/javascript"></script>
# <script src="https://files.newsnetz.ch/scripts/sm.js" type="text/javascript"></script>
#
# <!-- tracking_identifier:  -->
#
#
#         <meta name="c1_user_info" content="">
#
# <script>
#     var config = require("framework/config").config,
#         paywallInterface = require("framework/paywallInterface").paywallInterface,
#         paywallEventHandler = require("framework/paywallEventHandler").paywallEventHandler;
#
#     paywallInterface.configure($.extend({}, config, {
#         "paywall_status": config.paywall.status.enabled,
#         "eventHandler": paywallEventHandler
#     }));
#
#     paywallInterface.init().then(function() {
#         var url = window.location.href.toString().split(window.location.host)[1],
#             channels = url.split("/"),
#             regexResult = url.match(/.*\/story\/([0-9]{8})/i);
#
#         var premium = 0;
#
#         var trackingInfo = {
#             "cms_id": (regexResult ? regexResult[1] : 0),
#             "main_channel": (window.location.pathname === "/" ? "home" : channels[1]),
#             "sub_channel": channels[2],
#             "doc_type": (premium ? "premium" : (regexResult ? "article" : "section"))
#         }
#
#         // Check if the current site is a blog
#         if(window.location.host.indexOf("blog") > -1) {
#             channels = channels.filter(function(e, i) {
#                 return e !== "index.php" && e !== "category";
#             });
#
#             trackingInfo.sub_channel = "";
#             trackingInfo.doc_type = "section";
#
#             // Check if it is a blog article (if the third url section contains only numbers)
#             var regexResult = channels[2].match(/[0-9]+/i);
#             if(regexResult) {
#                 trackingInfo.cms_id = url;
#                 trackingInfo.doc_type = "article";
#             } else {
#                 trackingInfo.sub_channel = channels[2];
#             }
#         }
#
#         paywallInterface.track(trackingInfo);
#
#         // Track page complete event with ad blocker
#         $(window).load(function() {
#             ray.run(function(isDetected) {
#                 paywallInterface.track_pagecomplete($.extend({}, trackingInfo, {
#                     adblock: isDetected ? "full" : "no"
#                 }));
#             });
#         });
#     });
# </script>
#
#     <img style="display:none" src="https://mcdn.newsnetz.ch/upload/1/2/127790.png">
#     <img style="display:none" src="https://cdn.newsnetz.ch/upload/1/2/127790.png">
#     <img style="display:none" src="https://files.newsnetz.ch/upload/1/2/127790.png">
#     <img style="display:none" src="https://files2.newsnetz.ch/upload/1/2/127790.png">
#     <script src="https://files.newsnetz.ch/scripts/ghostbuster.min.js" type="text/javascript"></script>
#
#     <script>
#         window.dataLayer = window.dataLayer || [];
#     </script>
#
#     <!-- Google Tag Manager -->
#     <script>
#         if (! window.googleTagManagerStarted) {
#             // According to fabian, this code can be included multiple times per page, so we make sure at this point
#             // that we initialize gtm only once
#             window.googleTagManagerStarted = true;
#
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j ,f);
#             })(window,document,'script','dataLayer','GTM-B35JQ84');
#         }
#     </script>
#     <!-- End Google Tag Manager -->
#
#     <script>
#         // Add pageview tracking for GTM
#         var storyId = "",
#         premium = "",
#         article_title = "",
#         article_type = "",
#         publish_date = "0",
#         pageType = "front",
#         category = "front",
#         subcategory = "default";
#
#         if (publish_date == "0") {publish_date = "";}
#
#         var uid = undefined;
#         try {
#             uid = JSON.parse(document.querySelector("meta[name='c1_user_info']").getAttribute("content")).user_id;
#         }
#         catch(err) {
#             uid = undefined;
#         }
#
#         window.dataLayer.push({
#             "event": "pageview",
#             "pagetype": pageType,
#             "category": (category) ? category : "default",
#             "subcategory": (subcategory) ? subcategory : "default",
#             "article_id": (storyId) ? storyId : undefined,
#             "article_type": (article_type) ? article_type : undefined,
#             "uid": uid,
#             "article_title": (article_title) ? article_title : undefined,
#             "publish_date": (publish_date) ? publish_date : undefined,
#             "premium": (premium) ? premium : undefined
#         });
#
#         // Add Ghostbuster adblocker detection
#         var ray = new Ghostbuster();
#         ray.run(function(isDetected) {
#             if(isDetected) {
#                 window.dataLayer.push({
#                     "event": "Adblocker",
#                     "action": "detection"
#                 });
#             }
#         });
#     </script><div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links banner banner-top" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div><div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links banner banner-top" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div>
#
#     <!-- GOOGLE DFP TOP scripts start -->
#     <script src="//tdn.da-services.ch/current/tagesanzeiger.js"></script><iframe name="__cmpLocator" style="display: none;"></iframe>
#         <script>
#             var category = "front";
#             var subcategory = "default";
#             if (category == "default" || category == undefined)
#             {
#                 var nav1 = window.location.pathname.split("/")[1];
#                 var nav2 = window.location.pathname.split("/")[2];
#                 if (nav1) { category = nav1; }
#                 if (nav2) { subcategory = nav2; }
#             }
#             var adPath = category + "/" + subcategory;
#
#             TATM.init("de-tagesanzeiger.ch", adPath, {}, false, 1024);
#         </script>
#         <!--
#             TATM.init("de-tagi.ch,"front/default", 1, 2, 3);
#             1. Parameter (ex. var tatmParams = {storyid: 1234567};)
#             2. Stringfied dom-node (ex. "<p>Werbung</p>") | inactive/invisible = false
#             3. Website content-width (ex. 1024)
#         -->
#
#     <!--
#         used to change the ad path
#         old: de-tagesanzeiger.ch/front/default/overlay
#         new: de-tagesanzeiger.ch/overlay/front/default
#     -->
#     <script>
#     var ads = require("framework/ads/ads").ads;
#     var config = require("framework/config").config;
#     ads.configure(config);
#     ads.init();
#
#     TATM.adUnitFirst = true;
#     </script>
#
#
#     <script>
#     function TATMdisplayAds() {
#         if (!TATM.loadAdsActive) {
#             TATM.displayAds();
#         }
#     }
#     </script>
#     <!-- GOOGLE DFP TOP scripts end -->
#     <div id="ad-overlay-304316606"></div>
# 			<script>
#
#
# 				TATM.core.initAdUnits([{
# 					adUnitName: "overlay",
# 					targetContainerId: "ad-overlay-304316606"
# 				}]);
# 			</script>
#
#     <!-- Socio-Demographic Targeting script start-->
#     <script>
#         tamediaBID = null;
#
#         function initTamediaBID() {
#             if (!tamediaBID) {
#                 try {
#                     tamediaBID = "publishing/"+JSON.parse(document.querySelector("meta[name='c1_user_info']").getAttribute("content")).user_id;
#                 }
#                 catch(err) {
#                     tamediaBID = null;
#                 }
#             }
#         };
#     </script>
#     <!-- Socio-Demographic Targeting script end-->
#
#     <script>
#     window.onload = function() {
#         initTamediaBID();
#     };
#     setTimeout(function(){
#         initTamediaBID();
#     }, 1000);
#
#     setTimeout(function(){
#         TATMdisplayAds();
#     }, 5000);
#     </script>
#
#
# <script>
#     window.redesign2014 = 1;
# </script>
#
#
#
#
#     <!-- head_scripts_optimized ende -->
#
#     <!-- adtop start -->
#
#
# 			<style>
# 				.ad-outside-right { position: fixed; top: 28px; left: calc(50% + 512px); }
# 				@media screen and (max-width: 1626px) { .ad-outside-right { left: calc(100% - 300px); } }
# 				@media screen and (max-width: 1323px) { .ad-outside-right { left: 1024px; } }
# 			</style>
# 			<div class="ad-outside-right ad-position-sticky" id="ad-outside-right-494387441"><div id="tatm-ad-outside-right-494387441" data-google-query-id="CLSMit7Qm-UCFZkK4Aod5x8OaQ" data-dfp-creative="138289549724" data-dfp-campaign="2607298201" data-dfp-lineitem="5187682530" style=""><div id="google_ads_iframe_46753895/de-tagesanzeiger.ch/outside-right/front/default_0__container__" style="border: 0pt none; display: inline-block; width: 300px; height: 600px;"><iframe frameborder="0" src="https://tpc.googlesyndication.com/safeframe/1-0-35/html/container.html" id="google_ads_iframe_46753895/de-tagesanzeiger.ch/outside-right/front/default_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="300" height="600" data-is-safeframe="true" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" data-google-container-id="1" style="border: 0px; vertical-align: bottom;" data-load-complete="true"></iframe></div></div></div>
# 			<script>
#
#
# 				TATM.core.initAdUnits([{
# 					adUnitName: "outside-right",
# 					targetContainerId: "ad-outside-right-494387441"
# 				}]);
# 			</script>
#
#
# 			<style>
# 				.ad-outside-left { position: fixed; top: 28px; margin-left: -323px;; }
# 			</style>
# 			<div class="ad-outside-left" id="ad-outside-left-632058628"><div id="tatm-ad-outside-left-632058628"></div></div>
# 			<script>
#
#
# 				TATM.core.initAdUnits([{
# 					adUnitName: "outside-left",
# 					targetContainerId: "ad-outside-left-632058628"
# 				}]);
# 			</script>
#
#
# 			<div class="ad-content-ad" id="ad-content-ad-853136988"><div id="tatm-ad-content-ad-853136988" data-google-query-id="CLWMit7Qm-UCFZkK4Aod5x8OaQ" style="display: none;"><div id="google_ads_iframe_46753895/de-tagesanzeiger.ch/content-ad/front/default_0__container__" style="border: 0pt none; width: 1px; height: 1px;"></div></div></div>
# 			<script>
#
#
# 				TATM.core.initAdUnits([{
# 					adUnitName: "content-ad",
# 					targetContainerId: "ad-content-ad-853136988"
# 				}]);
# 			</script>
#
#     <!-- adtop ende -->
#
#
#
#
#
# <div id="mainContainer">
# 	<!-- The following div is needed by posterAd -->
# 	<div class="beforePosterAd">
# 		<div id="headerWrapper">
#
#     <section id="header">
#         <div id="topNav">
#     <ul class="paywallUserNavigation">
#         <li><nav class="NnPaywallUserNavigation" data-reactid=".0"><div data-reactid=".0.0"><div class="login" data-reactid=".0.0.0"><a href="javascript:void(0);" data-reactid=".0.0.0.0">Login</a></div><div class="subscribe" data-reactid=".0.0.1"><a href="javascript:void(0);" data-reactid=".0.0.1.0">Abo ab CHF 18.-</a><div class="promotion" data-reactid=".0.0.1.1"><div data-reactid=".0.0.1.1.0"><p data-reactid=".0.0.1.1.0.0"><span data-reactid=".0.0.1.1.0.0.0">
#                         </span><span data-reactid=".0.0.1.1.0.0.1">Den Tages-Anzeiger online lesen für nur CHF 18.- im Monat.</span><span data-reactid=".0.0.1.1.0.0.2">
#                     </span></p><p data-reactid=".0.0.1.1.0.1"><img src="https://files.newsnetz.ch/upload/1/2/127596.png" alt="true" data-reactid=".0.0.1.1.0.1.0"></p><p data-reactid=".0.0.1.1.0.2"><span data-reactid=".0.0.1.1.0.2.0">
#                         </span><span data-reactid=".0.0.1.1.0.2.1">Ganz flexibel und jederzeit kündbar. Jetzt testen und unbegrenzten Zugriff geniessen.</span><span data-reactid=".0.0.1.1.0.2.2">
#                     </span></p><a href="javascript:void(0);" data-reactid=".0.0.1.1.0.3">Alle Angebote anzeigen</a></div></div></div></div></nav></li>
#     </ul>
#
#     <ul class="productNav">
#         <li>
#             <a href="http://tagesanzeiger.homegate.ch/homegate/index?layout=&amp;agency=&amp;utm_source=nn_TA&amp;utm_medium=liim&amp;utm_term=ies&amp;utm_campaign=partn_d" target="_blank">Immo</a>
#         </li>
#         <li>·</li>
#         <li>
#             <a href="http://tagesanzeiger.sich-erinnern.ch" target="_blank">Trauer</a>
#         </li>
#         <li>·</li>
# 		<li>
# 			<a title="Das Magazin" target="_blank" href="//www.dasmagazin.ch">Das Magazin</a>
#         </li>
#         <li>
#             <form action="//www.tagesanzeiger.ch/service/suche/suche.html?date=alle&amp;order=date" method="get">
#                 <span class="icon-search"></span>
#                 <input type="hidden" name="date" id="date" value="alle">
#                 <input type="hidden" name="order" id="order" value="date">
#                 <input class="innerBoxShadow" onfocus="searchFocus(this)" onblur="searchBlur(this)" name="key" type="text" value="Suche" title="Suche" id="headerSearch">
#                 <button title="Submit Search" class="btn"></button>
#             </form>
#         </li>
#     </ul>
#     <div class="clear"></div>
# </div>
#
# <script>
#     var paywallInterface = require("framework/paywallInterface").paywallInterface,
#         paywallEventHandler = require("framework/paywallEventHandler").paywallEventHandler,
#         paywallUserNavigation = require("framework/paywallUserNavigation/paywallUserNavigation").PaywallUserNavigation;
#
#     paywallUserNavigation.insert(
#         $("#topNav .paywallUserNavigation li")[0], {
#             "interface": paywallInterface,
#             "eventHandler": paywallEventHandler
#         }
#     );
# </script>
#         <div id="masthead">
#             <ul>
#
#         <li id="headerDate">
#             <div class="last-update">Letztes Update: <em>12:52 Uhr</em></div>
#         </li>
#
#
#         <li id="tagiLogo" class="frontLogo">
#             <a href="http://www.tagesanzeiger.ch" title="Tages-Anzeiger Startseite">
#                 <img src="//www.tagesanzeiger.ch/images/logos/frontLogo@2x.png" id="mainLogo" alt="Tages-Anzeiger" style="display:inline;">
#                 <script type="text/javascript">
#                     if (/iPad|iPod|iPhone/.test(navigator.userAgent) || window.devicePixelRatio > 1){
#                         document.getElementById('mainLogo').src = "//www.tagesanzeiger.ch/images/logos/frontLogo@2x.png";
#                     }
#                 </script>
#                 <noscript>
#                     <img src="//www.tagesanzeiger.ch/images/logos/frontLogo.png" id="mainLogo" alt="Tages-Anzeiger" />
#                 </noscript>
#             </a>
#         </li>
#
#
#
#                 <li id="headerWeather">
#                     <a href="http://www.tagesanzeiger.ch/wetter/zuerich" title="sonnig"><img src="https://files.newsnetz.ch//wetter/icons/160px/day/k_01.png"><br><span>11°/21 °</span></a>
#                 </li>
#
#
#
#             </ul>
#
#         </div>
#         <div class="clear"></div>
#
#         <div id="mainNav"><ul>
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/" class="active">Front</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/zuerich/" class="">Zürich</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/schweiz/" class="">Schweiz</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/ausland/" class="">International</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/wirtschaft/" class="">Wirtschaft</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/stock_market/uebersicht/" class="">Börse</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/sport/" class="">Sport</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/kultur/" class="">Kultur</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/reisen/" class="">Reisen</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/wissen/" class="">Wissen</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/auto/" class="">Auto</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/blogs/" class="">Blogs</a>
# 				</li>
#
# 				<li>
# 					<a href="http://www.tagesanzeiger.ch/panorama/" class="">Panorama</a>
# 				</li>
#
#     			<li class="dropdownNavi">
# 				<a href="javascript:void(0)">
# 					Mehr
# 					<span class="icon-down"></span>
# 				</a>
# 				<ul>
# 					<!--[if IE 8]><div id="ie8"><![endif]-->
# 					<li class="epaper"><a href="http://epaper.tagesanzeiger.ch/" target="_blank">E-Paper</a></li>
# 					<li class="sonntagszeitung"><a href="http://www.tagesanzeiger.ch/sonntagszeitung/">SonntagsZeitung</a></li>
# 					<li class="digital"><a href="http://www.tagesanzeiger.ch/digital/">Digital</a></li>
# 					<li class="leben"><a href="http://www.tagesanzeiger.ch/leben/">Leben</a></li>
# 					<li class="forum"><a href="http://www.tagesanzeiger.ch/forum/">Forum</a></li>
# 					<li class="longform"><a href="http://www.tagesanzeiger.ch/longform/">Web-Spezial</a></li>
# 					<li class="dasMagazin"><a href="http://epaper.dasmagazin.ch" target="_blank">Das Magazin</a></li>
# 					<li class="zhTipp"><a href="http://www.tagesanzeiger.ch/zueritipp">Züritipp</a></li>
# 					<li class="krankenkassen"><a href="https://s3-eu-west-1.amazonaws.com/media.das.tamedia.ch/comparis/index.html?mandant=tagesanzeiger&amp;utm_source=newsnet&amp;utm_medium=banner&amp;utm_campaign=kk-herbst-de&amp;utm_content=desktop-mobile-app-201709-navigation-newsnet">Krankenkassen</a></li>
# 					<li class="autoversicherung"><a href="https://s3-eu-west-1.amazonaws.com/media.das.tamedia.ch/comparis/auto/index.html?mandant=tagesanzeiger">Autoversicherung</a></li>
# 					<li class="carteBlanche"><a href="http://www.tagesanzeiger.ch/carteblanche/">Carte Blanche</a></li>
# 					<li class="weiterbildung"><a href="http://weiterbildung.tagesanzeiger.ch/">Weiterbildung</a></li>
# 					<li class="eva"><a href="http://www.tagesanzeiger.ch/bildstrecke.html?id=24883">Eva</a></li>
# 					<li class="agenda"><a href="http://agenda.zueritipp.ch">Agenda</a></li>
# 					<!--[if IE 8]></div><![endif]-->
# 				</ul>
# 			</li>
# 		</ul></div>
# 			<script type="text/javascript">
# 				jQuery(function() {
#
# 				    jQuery("li.dropdownNavi").each(function(i){
# 				      jQuery(this).hover(function(){
# 				      	jQuery(this).find("ul").slice(0,1).addClass("activeDD");
# 				      	jQuery(this).find(".icon-down").removeClass().addClass("icon-up");
# 				      	},function(){
# 				      		jQuery(this).find("ul").slice(0,1).removeClass("activeDD");
# 				      		jQuery(this).find(".icon-up").removeClass().addClass("icon-down");
# 				      	});
# 				    });
#
# 				    // IE6 Fix:
# 				    if(jQuery.browser.msie && (jQuery.browser.version < 7)) {
# 				      jQuery("li.dropdownNavi").each(function(i){
# 				        jQuery(this).find("ul").hover(function(){jQuery(this).addClass("activeDD");},function(){jQuery(this).removeClass("activeDD");});
# 				      });
# 				    }
#
# 			  });
# 			</script>
#
#
#     </section>
#
# 		</div>
#
# 		<!-- Special-iFrame top -->
# 	    <!-- special top iframe -->
#
# 			<style>
# 				.ad-inside-full-top { margin-left: -7px; margin-top: 12px; }
# 			</style>
# 			<div class="ad-inside-full-top" id="ad-inside-full-top-811222774"><div id="tatm-ad-inside-full-top-811222774" data-google-query-id="CLaMit7Qm-UCFZkK4Aod5x8OaQ" data-dfp-creative="138286024334" data-dfp-campaign="2595526002" data-dfp-lineitem="5161566662" class="adf_outer_div" style="height: 562.125px;"><div id="google_ads_iframe_46753895/de-tagesanzeiger.ch/inside-full-top/front/default_0__container__" style="border: 0pt none; display: inline-block; width: 994px; height: 100%; max-width: 994px;"><iframe frameborder="0" src="https://tpc.googlesyndication.com/safeframe/1-0-35/html/container.html" id="google_ads_iframe_46753895/de-tagesanzeiger.ch/inside-full-top/front/default_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="994" height="250" data-is-safeframe="true" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" data-google-container-id="3" style="border: 0px; vertical-align: bottom; height: 100%; width: 994px; max-width: 994px;" data-load-complete="true"></iframe><style>div.ad-inside-full-top.fixed-banner {padding-bottom: 0px;} div.ad-inside-full-top.fixed-banner {position: fixed; top: 0; width: 978px; z-index: 5549; transition: 400ms top easeIn; margin-top:0px;} div.ad-inside-full-top.fixed-banner.push-down-banner {top: 30px;}</style></div></div></div>
# 			<script>
#
#
# 				TATM.core.initAdUnits([{
# 					adUnitName: "inside-full-top",
# 					targetContainerId: "ad-inside-full-top-811222774"
# 				}]);
# 			</script>
#
# 				<script>
# 					TATMdisplayAds();
# 				</script>
#
#
# 		<!-- special top2 iframe -->
# 		<!-- no data for ressort_1_6733360 -->
# 		<!-- no data for ressort_1_4662 -->
#
# 		<div id="mainColLeft" class="left">
# 			<!-- Begin Storylist -->
#
# <!-- atype=200 666-->
#             <div id="topStoryA">
#                 <div class="featureStory standard layout_2">
#
#
#                     <h3>
#                         <a href="/ausland/europa/queen-verliest-johnsons-rede/story/13706331">
#                             «Queen's Speech» zum Start in den Brexit-Showdown
#                         </a>
#                     </h3>
#                     <a href="/ausland/europa/queen-verliest-johnsons-rede/story/13706331"><img alt="" src="https://files.newsnetz.ch/story/1/3/7/13706331/13/linke_spalte_a_story.jpg" class="imgfloat"></a>
#                     <p>
#
#
#
#
#                         Die entscheidende Woche für die Briten beginnt: Was sagte die Königin vor dem Parlament?
#                         <a href="/ausland/europa/queen-verliest-johnsons-rede/story/13706331">Mehr...</a>
# ...
#
# <div class="diamond-advantages-page-wrap" id="diamond-advantages-page-wrap-id" style="display: none;" data-overlay-name="overlay-anonymous-front">
# 	<div class="diamond-advantages-main-container" id="diamond-advantages-main-container-id">
# 		<div class="diamond-registration-advantages-header" id="diamond-registration-advantages-header-id">
# 			<div id="tamovl-pw-head" style="padding-right: 20px">
# 				<a href="#" id="diamond_overlay_close" class="diamond-registration-advantages-link-grey">
#                 	<span class="diamond-redirection-grey">Schliessen</span>
#                 	<img class="mobile-overlay-close" src="https://abopage-mediafiles.tagesanzeiger.ch/logos/close_button1x.svg">
#                 </a>
#             </div>
# 		</div>
# 		<div class="diamond-registration-advantages-content" id="diamond-registration-advantages-content-id">
# 			<div class="diamond-registration-advantages-left-right diamond-registration-advantages-left" id="diamond-registration-advantages-left-id">
# 				<div class="diamond-registration-left-title" id="diamond-registration-left-title-id">
# 					Einloggen und <br> profitieren
# 				</div>
# 				<div class="diamond-registration-advantages-content-left" id="diamond-registration-advantages-content-left-id">
# 					<p class="style-dm-serif-text">
# 						Registrieren Sie sich in nur wenigen Klicks und geniessen Sie folgende Vorteile:
# 					</p>
# 					<div class="tam-horizontalDiv">
# 						<div class="tam-column-width-1">
# 							<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
# 						</div>
# 						<div class="tam-column-width-11">
# 							<p>
# 								Redaktioneller Newsletter
# 							</p>
# 						</div>
# 					</div>
#
# 					<div class="tam-horizontalDiv">
# 						<div class="tam-column-width-1">
# 							<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
# 						</div>
# 						<div class="tam-column-width-11">
# 							<p>
# 								Auch ohne Abo <span class="diamond-registration-advantages-blue">jede Woche 1 Abo+ Artikel gratis </span> lesen
# 							</p>
# 						</div>
# 					</div>
#
# 					<div class="tam-horizontalDiv">
# 						<div class="tam-column-width-1">
# 							<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
# 						</div>
# 						<div class="tam-column-width-11">
# 							<p>
# 								Ein Login für alle Partnerseiten und Apps
# 							</p>
# 						</div>
# 					</div>
# 					<div class="tam-horizontalDiv">
# 						<div class="tam-column-width-1">
# 						</div>
# 						<div class="tam-column-width-11">
# 							<p>
# 								<a href="#" id="diamond-mehr-erfahren-id" class="diamond-registration-advantages-link-grey">
# 									<span class="diamond-redirection-grey">Mehr erfahren</span>
# 									<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/right_icon.svg">
# 								</a>
# 							</p>
# 						</div>
# 					</div>
# 					<br>
# 				</div>
# 			</div>
# 			<div class="diamond-registration-advantages-bar" id="diamond-registration-advantages-bar-id">
# 			</div>
# 			<div class="diamond-registration-advantages-left-right" id="diamond-registration-advantages-right-id">
# 				<div class="diamond-registration-right-title" id="diamond-registration-right-title-id">
# 					Jetzt loslegen
# 				</div>
#
# 				<div class="diamond-registration-advantages-content-right" id="diamond-registration-advantages-content-right-id">
# 					<p class="style-dm-serif-text">
# 						Jetzt registrieren und <span class="diamond-registration-advantages-blue">jede <br> Woche 1 Abo+ Artikel gratis</span> erhalten.
# 					</p>
# 					<br>
# 					<p>
# 						<a class="diamond-advantages-button" id="diamond-advantages-button-id">
# 							Kostenlos registrieren
# 						</a>
# 					</p>
#
# 					 <hr class="horizontal-bar">
# 					 <br>
# 					<p class="footer-link">
# 							Bereits Kunde?
# 						<a class="diamond-redirection" id="diamond-melden-sie-sich-an-id">
# 							Melden Sie sich an
# 						</a>
# 					</p>
# 					<p class="footer-link">
# 							Besitzen Sie ein Zeitungs-Abo?
# 						<a class="diamond-redirection" id="diamond-konto-aktivieren-id">
# 							Konto aktivieren
# 						</a>
# 					</p>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
#
# <!-- Diamond Front page Mobile Version -->
#
# 	<div class="diamond-mobile-not-logged-main-container" id="diamond-mobile-advantages-main-container-id">
# 		<div class="diamond-mobile-not-logged-registration-header" id="diamond-mobile-registration-advantages-header-id">
# 			<a href="#" id="diamond-mobile-overlay-close" class="diamond-registration-advantages-link-grey">
# 				<span class="diamond-redirection-grey">Überspringen</span>
# 				<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/right_icon.svg">
# 			</a>
# 		</div>
#         <div id="diamond-mobile-registration-advantages-left-id">
#             <div class="diamond-mobile-not-logged-registration-title" id="diamond-mobile-registration-left-title-id">
#                 Einloggen und <br> profitieren
#             </div>
#             <div class="diamond-mobile-registration-advantages" id="diamond-mobile-registration-advantages-content-left-id">
#                 <p class="style-dm-serif-text">
#                 	Einloggen und
#                     	<span class="diamond-mobile-registration-advantages-blue">
#                     	jede Woche 1 Abo+ Artikel gratis
#                     	</span> erhalten.
#                 </p>
#                 <div class="tam-horizontalDiv">
#                 		<div class="tam-column-width-1">
#                 			<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
#                 	</div>
#     				<div class="tam-column-width-10">
#     				<p>
#     					Speichern Sie Artikel zum später lesen
#                     </p>
#     				</div>
#     			</div>
#
#                 <div class="tam-horizontalDiv">
#                 	<div class="tam-column-width-1">
#                 		<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
#                 	</div>
#     				<div class="tam-column-width-10">
#     				<p>
#     					Redaktioneller Newsletter
#                     </p>
#     				</div>
#     			</div>
#
#                 <div class="tam-horizontalDiv">
#                 	<div class="tam-column-width-1">
#                 		<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/green_check.svg">
#                 	</div>
#     				<div class="tam-column-width-10">
#     					<p>
#                     		Ein Login für alle Partnerseiten und Apps
#                     	</p>
#                     </div>
#                 </div>
#                 <br>
#                 <div class="tam-horizontalDiv padding-bottom-style">
#                 	<div class="tam-column-width-1"></div>
#                 	<div class="tam-column-width-10">
#                 			<p>
#                 				<a href="#" id="diamond-mobile-mehr-erfahren-id" class="diamond-registration-advantages-link-grey">
# 					   				<span class="diamond-redirection-grey">Mehr erfahren</span>
# 								<img src="https://abopage-mediafiles.tagesanzeiger.ch/logos/right_icon.svg">
# 								</a>
# 							</p>
#                 	</div>
#             	</div>
# 				<p>
#                 	<a class="diamond-advantages-button" id="diamond-registration-mobile-button-id">
#                 		Jetzt profitieren
#                 	</a>
#                 </p>
#                 <div class="padding-top-style">
#                 	<hr class="horizontal-bar"> <br>
#                 </div>
#                 <p class="footer-link">
#                     Bereits Kunde?
#                     <a class="diamond-redirection" id="diamond-mobile-melden-sie-sich-an-id">
#                     	Melden Sie sich an
#                     </a>
#                 </p>
#                 <p class="footer-link">
#                 	Besitzen Sie ein Zeitungs-Abo?
#                     <a class="diamond-redirection" id="diamond-mobile-konto-aktivieren-id">
#                     	Konto aktivieren
#                     </a>
#                 </p>
#                 <br>
# 			</div>
# 		</div>
# 	</div>
#
# </div>
#
# </div><div class="kxhead" data-id="KVqVXOwf" style="display:none !important;"><span class="kxtag kxinvisible" data-id="7795">
# <script>
# (function() {
#
#     Krux('scrape', {
#         'page_attr_url_path_1': {
#             'url_path': '1'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_url_path_2': {
#             'url_path': '2'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_url_path_3': {
#             'url_path': '3'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_url_path_4': {
#             'url_path': '4'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_url_path_5': {
#             'url_path': '5'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_url_path_6': {
#             'url_path': '6'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_meta_keywords': {
#             meta_name: 'keywords'
#         }
#     });
#     Krux('scrape', {
#         'page_attr_domain': {
#             url_domain: '2'
#         }
#     });
#
# })();
# </script></span><span class="kxtag kxinvisible" data-id="17849"><script>
# (function(){
# 	var find = Krux('require:sizzle').find;
# 	var site = Krux('scrape.url_host','2');
# 	var scrape_obj = {};
#
# 	//pulling in all values via dom_multi
# 	function setscrape(author,story_tags){
# 		scrape_obj['page_attr_'+site+'_author'] = {'dom_multi':author};
# 		scrape_obj['page_attr_'+site+'_story_tags'] = {'dom_multi':story_tags};
# 	}
#
# 	//specific tag locations for various sites
# 	site == '20min' && setscrape('p.autor:text','');
# 	site == 'annabelle' && setscrape('','div.stichworte li:text');
# 	site == 'bilan' && setscrape('strong.author a[href]:text','ul.field-topic li:text');
# 	site == 'tilllate' && setscrape('span[itemprop="author"] span:text','');
# 	site == 'friday-magazine' && setscrape('a.entry_header--details--author_link:text','');
# 	site == 'fuw' && setscrape('','div.aside1 li:text');
#
# 	if(site == 'femina'){
# 		var tags = Krux('require:sizzle').find('div.field-item.even');
# 		var tags_length = tags.tags_length;
# 		for(var i=0; i<tags_length; i++){
# 			if(!tags[i].hasChildNodes()){
# 				var author = tags[i].innerText || tags[i].textContent;
# 				Krux('set','page_attr_femina_author', author);
# 				break;
# 			}
# 		}
# 		setscrape('','div.field-item.even a[href]:text');
# 	}
#
# 	else if(site == 'bazonline' || site == 'bernerzeitung' || site == 'derbund' || site == 'tagesanzeiger'){
# 		setscrape('span.author:text','div.contextBox.keywordBox a[href]:text');
# 	}
#
# 	Krux('scrape',scrape_obj);
# })();
# </script></span><span class="kxtag kxinvisible" data-id="19563"><script>
#   if (document.getElementsByClassName("contextBox keywordBox")[0]){
#   	var pagetagsarray = document.getElementsByClassName("contextBox keywordBox")[0].textContent.replace('Stichworte', '').replace(/\s+/g,',').split(',');
# 	pagetagsgroups = "";
#   pagetagssingle = "";
# for (i=1; i<pagetagsarray.length-1; i++)
#   {
# 	pagetagssingle = pagetagsarray[i];
# 	pagetagsgroups = pagetagsgroups + ", " + pagetagssingle
#     // Using pagetagssingle to produce page attribute pagetagssingle
# 	Krux('scrape', { 'page_attr_pagetagssingle': {js_global: pagetagssingle[i]}});
#   }
#   // Using page_attr_pagetagsgroups to produce page attribute page_attr_pagetagsgroups
# 	Krux('scrape', { 'page_attr_pagetagsgroups': {js_global: "pagetagsgroups"}});
#   }
#
# </script></span><span class="kxtag kxinvisible" data-id="24238"><script>
# (function() {
#
#     var _kx = Krux,
#         pixelFired = false;
#     _kx('onOnce:pixel', function() {
#         pixelFired = true;
#     });
#
#     function setID() {
#         if (window.tamediaBID) {
#             _kx('scrape', {
#                 'user_attr_tamediaBID': {
#                     'js_global': 'tamediaBID'
#                 }
#             });
#             if (pixelFired) {
#                 _kx('require:pixel').send('', false);
#             }
#             clearInterval(interval);
#         }
#     }
#
#     var interval = setInterval(setID, 1000);
#
#     //Retrieve User IDs for Tamedia via ricardo.ch , 20min.ch and http://www.tutti.ch/zuerich
#     Krux('scrape', {
#         // tamediaBID_loaded is populated by the client as soon as the asynchronous script filled tamediaBID
#         // we ingest it here for getting an idea about how often the BID is filled before our pixel fires and ow many times we would need to fire another pixel once the async script completed
#         'page_attr_tamediaBID_loaded': {
#             js_global: "tamediaBID_loaded"
#         }
#     });
#
# })();
# </script></span><span class="kxtag kxinvisible" data-id="26571">
# <script>
# (function() {
#
#     //has tamedia id (for client to track population of logged in users)
#     var loggedInUser = 0; //0 if user not logged in, otherwise 1.
#     if (typeof tamediaBID !== 'undefined' && tamediaBID !== null) {
#         loggedInUser = 1;
#     }
#     Krux('set', 'user_attr_loggedInUser', loggedInUser);
#
# })();
# </script></span><span class="kxtag kxinvisible" data-id="32722"><script>
# (function() {
#     var dataObj = Krux('scrape.javascript', 'dataLayer'),
#         userKeys = 'undefined',
#         omitKeys = 'undefined',
#         custDelimit = 'undefined',
#         prefix = 'newsnet_',
#         config = {
#             'userKeys': userKeys ? userKeys.split(',') : undefined,
#             'omitKeys': (omitKeys ? omitKeys.split(',') : []).concat([
#                 /gtm\./, // GTM events
#                 /sessionid/i, // Session ids
#                 /\.phpsessid$/i, // Session ids
#                 /\.sid$/i, // Session ids
#                 /\.zenid$/i, // Session ids
#                 /\.requestid$/i // Request ids
#             ]),
#             'omitValues': [
#                 /.*@.*(?:\..*)+/, // Email Addresses
#                 /gtm\./, // GTM events
#                 /^(https?:)?\/\/[^\/]+/, // URLs
#                 /^\/[^\/]+/, // URL paths
#                 /.{255}/ // Long values
#             ],
#             'customDelimited': custDelimit ? custDelimit.split(',') : undefined,
#             'caseSensitive': 'false' === 'true',
#             'useFullPath': 'false' === 'true',
#             'useLastValue': 'false' === 'true',
#             'convertAttrNames': []
#         };
#     if (!prefix.match(/^$|null|undefined|false/)) {
#         config.convertAttrNames.push({
#             pattern: /((?:page|user)_attr_)/,
#             replacement: '$1' + prefix
#         });
#     }
#     Krux('ingestDataLayer', dataObj, config);
# }).call();
# </script></span><span class="kxtag kxinvisible" data-id="40689"><script>
#
# if('kkpid'.length>0
#   && Krux('require:store').cookie.get('kkpid').length>0
# ){
#   Krux('require:store').cookie.set('kppid', Krux('require:store').cookie.get('kkpid'));
# }
#
# </script></span></div><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nzwvg&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.tagesanzeiger.ch%2F" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nzfcr&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.tagesanzeiger.ch%2F" type="text/javascript"></script><div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links banner banner-top" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div><div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links banner banner-top" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div></body><iframe id="kx-proxy-KVqVXOwf" src="https://cdn.krxd.net/partnerjs/xdi/proxy.3d2100fd7107262ecb55ce6847f01fa5.html#!kxcid=KVqVXOwf&amp;kxt=https%3A%2F%2Fwww.tagesanzeiger.ch&amp;kxcl=cdn&amp;kxp=" style="display: none; visibility: hidden; height: 0; width: 0;"></iframe></html>
